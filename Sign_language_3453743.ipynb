# %% [markdown]
# <a href="https://colab.research.google.com/github/hamnaaj112-cmd/EcoStep/blob/main/Sign_language_3453743.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
/content/drive/MyDrive/sign_mnist_test.csv   - sign_mnist_test.csv
/content/drive/MyDrive/sign_mnist_train.csv  - sign_mnist_train.csv

# %% [markdown]
# Data paths
# /content/drive/MyDrive/sign_mnist_test.csv   - sign_mnist_test.csv
# /content/drive/MyDrive/sign_mnist_train.csv  - sign_mnist_train.csv

# %% [markdown]
# # **1. Loading CSV Files**
